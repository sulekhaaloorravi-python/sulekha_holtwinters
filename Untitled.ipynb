# %%
import pandas as pd

# %%
df = pd.read_csv("FoodBalanceSheets_E_All_Data_NOFLAG.csv",encoding = "ISO-8859-1")

# %%
df.head(5)
# Out:
#    Area Code         Area  Item Code              Item  Element Code  \
# 0          2  Afghanistan       2501        Population           511
# 1          2  Afghanistan       2901       Grand Total           664
# 2          2  Afghanistan       2901       Grand Total           674
# 3          2  Afghanistan       2901       Grand Total           684
# 4          2  Afghanistan       2903  Vegetal Products           664
#
#                                   Element             Unit    Y1961    Y1962  \
# 0           Total Population - Both sexes     1000 persons  8954.00  9142.00
# 1           Food supply (kcal/capita/day)  kcal/capita/day  2999.00  2917.00
# 2  Protein supply quantity (g/capita/day)     g/capita/day    84.91    82.98
# 3      Fat supply quantity (g/capita/day)     g/capita/day    37.51    37.61
# 4           Food supply (kcal/capita/day)  kcal/capita/day  2752.00  2672.00
#
#      Y1963    ...        Y2004     Y2005     Y2006     Y2007     Y2008  \
# ...

# %%
df.describe()
# Out:
#            Area Code      Item Code   Element Code         Y1961  \
# count  238560.000000  238560.000000  238560.000000  2.071060e+05
# mean     1150.202192    2696.283342    3706.402067  5.064011e+02
# std      2081.530727     147.605837    2277.037152  1.105230e+04
# min         1.000000    2501.000000     511.000000 -1.425500e+04
# 25%        81.000000    2570.000000     674.000000  0.000000e+00
# 50%       155.000000    2641.000000    5142.000000  1.900000e-01
# 75%       236.000000    2782.000000    5511.000000  1.100000e+01
# max      5817.000000    2961.000000    5911.000000  3.047759e+06
#
#               Y1962         Y1963         Y1964         Y1965         Y1966  \
# count  2.071060e+05  2.071060e+05  2.071060e+05  2.071060e+05  2.071060e+05
# mean   5.161298e+02  5.282580e+02  5.536915e+02  5.755501e+02  5.911821e+02
# std    1.120759e+04  1.141292e+04  1.183959e+04  1.218371e+04  1.250029e+04
# ...

# %%
missing_values=df.columns[df.isnull().any()]
df[missing_values].isnull().sum()
# Out:
# Y1961    31454
# Y1962    31454
# Y1963    31454
# Y1964    31454
# Y1965    31454
# Y1966    31454
# Y1967    31454
# Y1968    31454
# Y1969    31454
# Y1970    31454
# Y1971    31454
# Y1972    31454
# Y1973    31454
# Y1974    31454
# Y1975    31454
# Y1976    31454
# Y1977    31454
# Y1978    31454
# Y1979    31454
# Y1980    31454
# Y1981    31454
# Y1982    31454
# Y1983    31454
# Y1984    31454
# Y1985    31454
# Y1986    31454
# Y1987    31454
# Y1988    31454
# Y1989    31454
# Y1990    30407
# Y1991    30407
# Y1992    10511
# Y1993     9104
# Y1994     9104
# Y1995     9104
# Y1996     9104
# Y1997     9104
# Y1998     9104
# Y1999     9104
# Y2000     8131
# Y2001     8131
# Y2002     8131
# Y2003     8131
# Y2004     8131
# Y2005     8131
# Y2006     7269
# Y2007     7269
# Y2008     7269
# Y2009     7269
# Y2010     7269
# Y2011     8002
# Y2012     8218
# Y2013     8218
# dtype: int64

# %%
df_impute = df[df.isnull().any(axis=1)][missing_values]

# %% [markdown]
# for index, row in df_impute.iterrows():
#     print(index)
